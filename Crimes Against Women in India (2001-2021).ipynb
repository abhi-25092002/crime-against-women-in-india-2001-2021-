# %% [markdown]
# # Crimes Against Women in India (2001-2021)

# %% [markdown]
# 1. WHICH AREA HIGHEST CRIMES AGAINST WOMEN IN INDIA

# %% [markdown]
#   2.WHICH YEAR HIGHEST CRIMES AGAINST WOMEN IN INDIA

# %% [markdown]
# 3.CHECKING CRIME YEAR REGARDING AREA

# %% [markdown]
# 4.CHECKING STATE ACCORDING RAPE CASES

# %% [markdown]
# 5.YEAR REGARDING KIDNAP AND ASSULT CASES

# %% [markdown]
# 6.CHECKING STATE WISE AoW CRIMES

# %% [markdown]
# 7.YEAR ACCORDING WT AND DV CRIMES AGAINST WOMEN IN INDIA

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dt = pd.read_csv(r"C:\Users\abhip\Documents\Downloads\Crimes Against Women in India (2001-2021)\CrimesOnWomenData.csv")
dt
# Out:
#      Unnamed: 0              State  Year  Rape   K&A   DD   AoW   AoM    DV  \
# 0             0     ANDHRA PRADESH  2001   871   765  420  3544  2271  5791
# 1             1  ARUNACHAL PRADESH  2001    33    55    0    78     3    11
# 2             2              ASSAM  2001   817  1070   59   850     4  1248
# 3             3              BIHAR  2001   888   518  859   562    21  1558
# 4             4       CHHATTISGARH  2001   959   171   70  1763   161   840
# ..          ...                ...   ...   ...   ...  ...   ...   ...   ...
# 731         731         D&N Haveli  2021  1250  4083  141  2068   417  4731
# 732         732        Daman & Diu  2021   315   904   16  1851    10   501
# 733         733           Delhi UT  2021     2     1    0     5     1     9
# 734         734        Lakshadweep  2021     0     0    0     1     1     3
# 735         735         Puducherry  2021     2     0    2    31     3    12
#
#      WT
# 0     7
# 1     0
# 2     0
# 3    83
# ...

# %% [markdown]
# 1.K&A - Kidnap And Assault

# %% [markdown]
# 2.DD - Dowry Deaths

# %% [markdown]
# 3.AoW-Assault againts women

# %% [markdown]
# 4.AoM - Assault againts modesty of women

# %% [markdown]
# 5.DV-Domestic Violence

# %% [markdown]
# 6.WT - Women Trafficking

# %%
dt.columns
# Out:
# Index(['Unnamed: 0', 'State', 'Year', 'Rape', 'K&A', 'DD', 'AoW', 'AoM', 'DV',
#        'WT'],
#       dtype='object')

# %%
dt.describe(include='all')
# Out:
#         Unnamed: 0              State         Year         Rape           K&A  \
# count   736.000000                736   736.000000   736.000000    736.000000
# unique         NaN                 70          NaN          NaN           NaN
# top            NaN  Arunachal Pradesh          NaN          NaN           NaN
# freq           NaN                 11          NaN          NaN           NaN
# mean    367.500000                NaN  2011.149457   727.855978   1134.542120
# std     212.609188                NaN     6.053453   977.024945   1993.536828
# min       0.000000                NaN  2001.000000     0.000000      0.000000
# 25%     183.750000                NaN  2006.000000    35.000000     24.750000
# 50%     367.500000                NaN  2011.000000   348.500000    290.000000
# 75%     551.250000                NaN  2016.000000  1069.000000   1216.000000
# max     735.000000                NaN  2021.000000  6337.000000  15381.000000
#
# ...

# %%
dt.isnull().sum()
# Out:
# Unnamed: 0    0
# State         0
# Year          0
# Rape          0
# K&A           0
# DD            0
# AoW           0
# AoM           0
# DV            0
# WT            0
# dtype: int64

# %%
dt.dropna(how='any',inplace=True)

# %%
dt.head()
# Out:
#    Unnamed: 0              State  Year  Rape   K&A   DD   AoW   AoM    DV  WT
# 0           0     ANDHRA PRADESH  2001   871   765  420  3544  2271  5791   7
# 1           1  ARUNACHAL PRADESH  2001    33    55    0    78     3    11   0
# 2           2              ASSAM  2001   817  1070   59   850     4  1248   0
# 3           3              BIHAR  2001   888   518  859   562    21  1558  83
# 4           4       CHHATTISGARH  2001   959   171   70  1763   161   840   0

# %%
dt.tail()
# Out:
#      Unnamed: 0        State  Year  Rape   K&A   DD   AoW  AoM    DV  WT
# 731         731   D&N Haveli  2021  1250  4083  141  2068  417  4731   4
# 732         732  Daman & Diu  2021   315   904   16  1851   10   501   1
# 733         733     Delhi UT  2021     2     1    0     5    1     9   0
# 734         734  Lakshadweep  2021     0     0    0     1    1     3   0
# 735         735   Puducherry  2021     2     0    2    31    3    12   0

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 736 entries, 0 to 735
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  736 non-null    int64
#  1   State       736 non-null    object
#  2   Year        736 non-null    int64
#  3   Rape        736 non-null    int64
#  4   K&A         736 non-null    int64
#  5   DD          736 non-null    int64
#  6   AoW         736 non-null    int64
#  7   AoM         736 non-null    int64
#  8   DV          736 non-null    int64
#  9   WT          736 non-null    int64
# dtypes: int64(9), object(1)
# memory usage: 57.6+ KB

# %% [markdown]
# # DATA CLEANING :-

# %%
dt.dtypes
# Out:
# Unnamed: 0     int64
# State         object
# Year           int64
# Rape           int64
# K&A            int64
# DD             int64
# AoW            int64
# AoM            int64
# DV             int64
# WT             int64
# dtype: object

# %%
dt.head()
# Out:
#    Unnamed: 0              State  Year  Rape   K&A   DD   AoW   AoM    DV  WT
# 0           0     ANDHRA PRADESH  2001   871   765  420  3544  2271  5791   7
# 1           1  ARUNACHAL PRADESH  2001    33    55    0    78     3    11   0
# 2           2              ASSAM  2001   817  1070   59   850     4  1248   0
# 3           3              BIHAR  2001   888   518  859   562    21  1558  83
# 4           4       CHHATTISGARH  2001   959   171   70  1763   161   840   0

# %%
a = dt['State'].unique()
print(a)
# Out:
# ['ANDHRA PRADESH' 'ARUNACHAL PRADESH' 'ASSAM' 'BIHAR' 'CHHATTISGARH' 'GOA'
#  'GUJARAT' 'HARYANA' 'HIMACHAL PRADESH' 'JAMMU & KASHMIR' 'JHARKHAND'
#  'KARNATAKA' 'KERALA' 'MADHYA PRADESH' 'MAHARASHTRA' 'MANIPUR' 'MEGHALAYA'
#  'MIZORAM' 'NAGALAND' 'ODISHA' 'PUNJAB' 'RAJASTHAN' 'SIKKIM' 'TAMIL NADU'
#  'TRIPURA' 'UTTAR PRADESH' 'UTTARAKHAND' 'WEST BENGAL' 'A & N ISLANDS'
#  'CHANDIGARH' 'D & N HAVELI' 'DAMAN & DIU' 'LAKSHADWEEP' 'PUDUCHERRY'
#  'Andhra Pradesh' 'Arunachal Pradesh' 'Assam' 'Bihar' 'Chhattisgarh' 'Goa'
#  'Gujarat' 'Haryana' 'Himachal Pradesh' 'Jammu & Kashmir' 'Jharkhand'
#  'Karnataka' 'Kerala' 'Madhya Pradesh' 'Maharashtra' 'Manipur' 'Meghalaya'
#  'Mizoram' 'Nagaland' 'Odisha' 'Punjab' 'Rajasthan' 'Sikkim' 'Tamil Nadu'
#  'Telangana' 'Tripura' 'Uttar Pradesh' 'Uttarakhand' 'West Bengal'
#  'A & N Islands' 'Chandigarh' 'D&N Haveli' 'Daman & Diu' 'Delhi UT'
#  'Lakshadweep' 'Puducherry']

# %%
dt.size
# Out:
# 7360

# %%
dt.shape
# Out:
# (736, 10)

# %%
dt.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 731    False
# 732    False
# 733    False
# 734    False
# 735    False
# Length: 736, dtype: bool

# %%
dt.describe()
# Out:
#        Unnamed: 0         Year         Rape           K&A           DD  \
# count  736.000000   736.000000   736.000000    736.000000   736.000000
# mean   367.500000  2011.149457   727.855978   1134.542120   215.692935
# std    212.609188     6.053453   977.024945   1993.536828   424.927334
# min      0.000000  2001.000000     0.000000      0.000000     0.000000
# 25%    183.750000  2006.000000    35.000000     24.750000     1.000000
# 50%    367.500000  2011.000000   348.500000    290.000000    29.000000
# 75%    551.250000  2016.000000  1069.000000   1216.000000   259.000000
# max    735.000000  2021.000000  6337.000000  15381.000000  2524.000000
#
#                 AoW          AoM            DV          WT
# count    736.000000   736.000000    736.000000  736.000000
# mean    1579.115489   332.722826   2595.078804   28.744565
# std     2463.962518   806.024551   4042.004953   79.999660
# min        0.000000     0.000000      0.000000    0.000000
# ...

# %%
dt.head(10)
# Out:
#    Unnamed: 0              State  Year  Rape   K&A   DD   AoW   AoM    DV  WT
# 0           0     ANDHRA PRADESH  2001   871   765  420  3544  2271  5791   7
# 1           1  ARUNACHAL PRADESH  2001    33    55    0    78     3    11   0
# 2           2              ASSAM  2001   817  1070   59   850     4  1248   0
# 3           3              BIHAR  2001   888   518  859   562    21  1558  83
# 4           4       CHHATTISGARH  2001   959   171   70  1763   161   840   0
# 5           5                GOA  2001    12     6    2    17     7    11   0
# 6           6            GUJARAT  2001   286   857   67   756   111  3667   0
# 7           7            HARYANA  2001   398   297  285   478   401  1513   0
# 8           8   HIMACHAL PRADESH  2001   124   105   10   310    14   317   0
# 9           9    JAMMU & KASHMIR  2001   169   504   13   622   288    50   0

# %% [markdown]
# # VISULIZATION:-

# %% [markdown]
# # 1. WHICH AREA HIGHEST CRIMES AGAINST WOMEN IN INDIA

# %%
dt['State'].value_counts()[:].plot(kind='bar',color='purple',figsize=(25,10),title=('Which Area High Crime In India'))
# Out:
# <Axes: title={'center': 'Which Area High Crime In India'}, xlabel='State'>

# %% [markdown]
# # 2.WHICH YEAR HIGHEST CRIMES AGAINST WOMEN IN INDIA

# %%
dt['Year'].plot(kind='line',color='r',figsize=(25,10),title=('Which Year High Crime In India')).grid(color='black',linestyle='dotted',linewidth=0.5)

# %% [markdown]
# # 3.CHECKING CRIME YEAR REGARDING AREA

# %%
plt.subplots(figsize=(15,25))
sns.boxplot(y='State',x='Year',data=dt,palette='rainbow')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
dt.head(2)
# Out:
#    Unnamed: 0              State  Year  Rape  K&A   DD   AoW   AoM    DV  WT
# 0           0     ANDHRA PRADESH  2001   871  765  420  3544  2271  5791   7
# 1           1  ARUNACHAL PRADESH  2001    33   55    0    78     3    11   0

# %% [markdown]
# # 4.CHECKING STATE ACCORDING RAPE CASES

# %%
plt.subplots(figsize=(15,15))
sns.barplot(y='State',x='Rape',data=dt)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
dt.head()
# Out:
#    Unnamed: 0              State  Year  Rape   K&A   DD   AoW   AoM    DV  WT
# 0           0     ANDHRA PRADESH  2001   871   765  420  3544  2271  5791   7
# 1           1  ARUNACHAL PRADESH  2001    33    55    0    78     3    11   0
# 2           2              ASSAM  2001   817  1070   59   850     4  1248   0
# 3           3              BIHAR  2001   888   518  859   562    21  1558  83
# 4           4       CHHATTISGARH  2001   959   171   70  1763   161   840   0

# %% [markdown]
# # 5.YEAR REGARDING KIDNAP AND ASSULT CASES

# %%
plt.subplots(figsize=(15,5))
sns.boxplot(y='K&A',x='Year',data=dt)
plt.title('YEAR AND K&A CASES',fontsize=15,color='olive')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # 6.CHECKING STATE WISE AoW CRIMES

# %%
plt.figure(figsize=(15,15))
sns.scatterplot(x='AoW',y='State',data=dt)
plt.xlabel('Aow',size=20)
plt.ylabel('State',size=20)
# Out:
# Text(0, 0.5, 'State')

# %% [markdown]
# # 7.YEAR ACCORDING WT AND DV CRIMES AGAINST WOMEN IN INDIA

# %%
sns.lmplot(x='WT',y='Year',data=dt)
plt.xlabel('WT',size=15)
plt.ylabel('Year',size=15)
# Out:
# Text(15.625000000000009, 0.5, 'Year')

# %%
dt.head()
# Out:
#    Unnamed: 0              State  Year  Rape   K&A   DD   AoW   AoM    DV  WT
# 0           0     ANDHRA PRADESH  2001   871   765  420  3544  2271  5791   7
# 1           1  ARUNACHAL PRADESH  2001    33    55    0    78     3    11   0
# 2           2              ASSAM  2001   817  1070   59   850     4  1248   0
# 3           3              BIHAR  2001   888   518  859   562    21  1558  83
# 4           4       CHHATTISGARH  2001   959   171   70  1763   161   840   0

# %%
plt.subplots(figsize=(15,8))
sns.barplot(x='Year',y='DV',data=dt)
plt.title('WHICH YEAR HIGHEST DV CRIMES',color='g',fontsize=15)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # EDA :-

# %%
dt.hist(figsize=(25,20),color='gray')
# Out:
# array([[<Axes: title={'center': 'Unnamed: 0'}>,
#         <Axes: title={'center': 'Year'}>,
#         <Axes: title={'center': 'Rape'}>],
#        [<Axes: title={'center': 'K&A'}>, <Axes: title={'center': 'DD'}>,
#         <Axes: title={'center': 'AoW'}>],
#        [<Axes: title={'center': 'AoM'}>, <Axes: title={'center': 'DV'}>,
#         <Axes: title={'center': 'WT'}>]], dtype=object)

# %% [markdown]
# # BIVARIANT ANALYSIS :-

# %%
sns.pairplot(dt)
# Out:
# C:\Users\abhip\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\abhip\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\abhip\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
dt.head(10)
# Out:
#    Unnamed: 0              State  Year  Rape   K&A   DD   AoW   AoM    DV  WT
# 0           0     ANDHRA PRADESH  2001   871   765  420  3544  2271  5791   7
# 1           1  ARUNACHAL PRADESH  2001    33    55    0    78     3    11   0
# 2           2              ASSAM  2001   817  1070   59   850     4  1248   0
# 3           3              BIHAR  2001   888   518  859   562    21  1558  83
# 4           4       CHHATTISGARH  2001   959   171   70  1763   161   840   0
# 5           5                GOA  2001    12     6    2    17     7    11   0
# 6           6            GUJARAT  2001   286   857   67   756   111  3667   0
# 7           7            HARYANA  2001   398   297  285   478   401  1513   0
# 8           8   HIMACHAL PRADESH  2001   124   105   10   310    14   317   0
# 9           9    JAMMU & KASHMIR  2001   169   504   13   622   288    50   0

# %%
dt.tail(10)
# Out:
#      Unnamed: 0          State  Year  Rape   K&A   DD   AoW  AoM     DV  WT
# 726         726  Uttar Pradesh  2021   534   402   72   655   13    519  17
# 727         727    Uttarakhand  2021  1123  7376  454  2485  424  19952  50
# 728         728    West Bengal  2021    15     0    1    32    4      4   0
# 729         729  A & N Islands  2021    74   120    4    37    6     95   0
# 730         730     Chandigarh  2021     3    23    0     7    0      6   0
# 731         731     D&N Haveli  2021  1250  4083  141  2068  417   4731   4
# 732         732    Daman & Diu  2021   315   904   16  1851   10    501   1
# 733         733       Delhi UT  2021     2     1    0     5    1      9   0
# 734         734    Lakshadweep  2021     0     0    0     1    1      3   0
# 735         735     Puducherry  2021     2     0    2    31    3     12   0
